# %% [markdown]
# # Extracting table data from the web

# %%
# Setup
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

# %% [markdown]
# ## Get the web page and convert to dataframe

# %%
URL = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
res = requests.get(URL)
soup = BeautifulSoup(res.content, 'html.parser')
tables = soup.find_all('table')
table = tables[1] # note that the first table (at index 0) is not relevant

# Print the first 250 characters of the html table
print(str(table)[:250])
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr>
# <th data-sort-type="number">Rank</th>
# <th>Country<br/>(or dependent territory)</th>
# <th>Population</th>
# <th>Date</th>
# <th>% of world<br/>population</th>
# <th class="unsortable">So

# %% [markdown]
# ## # Convert html to pandas dataframe

# %%
df = pd.read_html(str(table), header=0)[0]
print(df.head(10).to_string())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-3a80ae1cfba8> in <module>()
# ----> 1 df = pd.read_html(str(table), header=0)[0]
#       2 print(df.head(10).to_string())
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     913                   thousands=thousands, attrs=attrs, encoding=encoding,
#     914                   decimal=decimal, converters=converters, na_values=na_values,
# --> 915                   keep_default_na=keep_default_na)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     737     retained = None
#     738     for flav in flavor:
# --> 739         parser = _parser_dispatch(flav)
#     740         p = parser(io, compiled_match, attrs, encoding)
#     741
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parser_dispatch(flavor)
#     695     else:
#     696         if not _HAS_LXML:
# --> 697             raise ImportError("lxml not found, please install it")
#     698     return _valid_parsers[flavor]
#     699
#
# ImportError: lxml not found, please install it
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Convert dataframe to json string

# %%
str_json = (df.head(10).to_json(orient='records'))
print(str_json)
# Out:
# [{"Rank":"1","Country(or dependent territory)":"China[Note 2]","Population":1393090000,"Date":"July 23, 2018","% of worldpopulation":"18.2%","Source":"Official population clock"},{"Rank":"2","Country(or dependent territory)":"India[Note 3]","Population":1334690000,"Date":"July 23, 2018","% of worldpopulation":"17.5%","Source":"Official population clock"},{"Rank":"3","Country(or dependent territory)":"United States[Note 4]","Population":327527000,"Date":"July 23, 2018","% of worldpopulation":"4.29%","Source":"Official population clock"},{"Rank":"4","Country(or dependent territory)":"Indonesia","Population":265015300,"Date":"July 1, 2018","% of worldpopulation":"3.47%","Source":"Official annual projection"},{"Rank":"5","Country(or dependent territory)":"Pakistan","Population":212335000,"Date":"July 23, 2018","% of worldpopulation":"2.78%","Source":"Official population clock"},{"Rank":"6","Country(or dependent territory)":"Brazil","Population":209350000,"Date":"July 23, 2018","% of worldpopulation":"2.74%","Source":"Official population clock"},{"Rank":"7","Country(or dependent territory)":"Nigeria","Population":193392517,"Date":"July 1, 2016","% of worldpopulation":"2.53%","Source":"Annual official estimate"},{"Rank":"8","Country(or dependent territory)":"Bangladesh","Population":164889000,"Date":"July 23, 2018","% of worldpopulation":"2.16%","Source":"Official population clock"},{"Rank":"9","Country(or dependent territory)":"Russia[Note 5]","Population":146877088,"Date":"January 1, 2018","% of worldpopulation":"1.92%","Source":"Official estimate"},{"Rank":"10","Country(or dependent territory)":"Japan","Population":126490000,"Date":"May 1, 2018","% of worldpopulation":"1.66%","Source":"Monthly provisional estimate"}]

# %% [markdown]
# ## Convert json string to list of dictionaries using 'json.loads'

# %%
li_json = json.loads(str_json)
for i,v in enumerate(li_json):
    print(i,v)
# Out:
# 0 {'Rank': '1', 'Country(or dependent territory)': 'China[Note 2]', 'Population': 1393090000, 'Date': 'July 23, 2018', '% of worldpopulation': '18.2%', 'Source': 'Official population clock'}
# 1 {'Rank': '2', 'Country(or dependent territory)': 'India[Note 3]', 'Population': 1334690000, 'Date': 'July 23, 2018', '% of worldpopulation': '17.5%', 'Source': 'Official population clock'}
# 2 {'Rank': '3', 'Country(or dependent territory)': 'United States[Note 4]', 'Population': 327527000, 'Date': 'July 23, 2018', '% of worldpopulation': '4.29%', 'Source': 'Official population clock'}
# 3 {'Rank': '4', 'Country(or dependent territory)': 'Indonesia', 'Population': 265015300, 'Date': 'July 1, 2018', '% of worldpopulation': '3.47%', 'Source': 'Official annual projection'}
# 4 {'Rank': '5', 'Country(or dependent territory)': 'Pakistan', 'Population': 212335000, 'Date': 'July 23, 2018', '% of worldpopulation': '2.78%', 'Source': 'Official population clock'}
# 5 {'Rank': '6', 'Country(or dependent territory)': 'Brazil', 'Population': 209350000, 'Date': 'July 23, 2018', '% of worldpopulation': '2.74%', 'Source': 'Official population clock'}
# 6 {'Rank': '7', 'Country(or dependent territory)': 'Nigeria', 'Population': 193392517, 'Date': 'July 1, 2016', '% of worldpopulation': '2.53%', 'Source': 'Annual official estimate'}
# 7 {'Rank': '8', 'Country(or dependent territory)': 'Bangladesh', 'Population': 164889000, 'Date': 'July 23, 2018', '% of worldpopulation': '2.16%', 'Source': 'Official population clock'}
# 8 {'Rank': '9', 'Country(or dependent territory)': 'Russia[Note 5]', 'Population': 146877088, 'Date': 'January 1, 2018', '% of worldpopulation': '1.92%', 'Source': 'Official estimate'}
# 9 {'Rank': '10', 'Country(or dependent territory)': 'Japan', 'Population': 126490000, 'Date': 'May 1, 2018', '% of worldpopulation': '1.66%', 'Source': 'Monthly provisional estimate'}
